# %%
#2D Array format: [[N],[BodyLength],[LegLength],[tau_a], [F_a], [leg angle], [rPos], [xPos], [zPos]]

# %%
import numpy as np
import csv
from numpy import load
import sympy as sym

import matplotlib.pyplot as plt
import matplotlib.animation as ani
from IPython.display import HTML
# load array
filenamefilename = "output/filenames.csv"
with open(filenamefilename) as fp:
    reader = csv.reader(fp, delimiter="\n", quotechar='"')
    for row in reader:
        fn = row[0]
# filenames = load(filenamefilename)
# filenames = filenames.strsplit('\n')
# filename = filenames[len(filenames)-1]

#fn = 'output/data20200921_220916at35.npy'      # specify timestamp of desired file and uncomment to not run the most recent data file
data = load(fn)
# print the array
print('data')
print(data)
print('====================')

print(fn)
#print("step     N        lbod      l1    l2      tau_h   tau_k  theta_l1  theta_l2  dz  dtl1   dtl2   z    tt")
for i in range(len(data[0])):
   # print(i, sep = '\t', end ='\t')
    print('\n')
    for j in range(len(data)):
        if j == 2:
#             print(',', end='')
            print((data[j][i]), sep = ',\t', end ='')
        else:
            if j == 0 or j == 1:
                print((data[j][i]), sep = ',\t', end ='')
            else:
#             if j == 2:
#                 ((data[j][i]), sep ='\t', end ='')
# #                 print('{:8.3f}'.format(data[j][i]*180/3.141592654), sep ='\t', end ='')
#             else:
# #                 print('{:8.4f}'.format(data[j][i]), sep ='\t', end ='')
                    print()
        
print('=======')

print('double wrongtrajHip[] = {', end="")
for i in range(len(data[0])):
    print((data[0][i]*180/3.141592654), sep ='\t', end ='')
    if i == len(data[0])-1:
        print('};')
    else:
        print(', ', end="")

print('double wrongtrajKnee[] = {', end="")
for i in range(len(data[1])):
    print((data[1][i]*180/3.141592654), sep ='\t', end ='')
    if i == len(data[0])-1:
        print('};')
    else:
        print(', ', end="")

print('double wrongtrajHM[] = {', end="")
for i in range(len(data[2])):
    print((data[2][i]), sep ='\t', end ='')
    if i == len(data[0])-1:
        print('};')
    else:
        print(', ', end="")

    
#print('================= Hip & Knee angles for Arduino:\n')
# for i in range(len(data[0])):
# #     print(i, sep ='\t', end ='\t')
#     for j in range(len(data)):
#         if j == 6 or j == 7:
# #             print('{:.3f}'.format(data[j][i]*180/3.141592654), sep ='\t', end ='')
#             print('{:.0f}'.format(data[j][i]*180/3.141592654), sep ='\t', end ='')
#         if j == 6:
#             print('\t', sep='\t', end='')
# #         else:
# #             print('{:.4f}'.format(data[j][i]), sep ='\t', end ='')
#     print()

# print('int trajHip[] = {', end="")
# for i in range(len(data[0])):
#     print((data[0][i]*180/3.141592654), sep ='\t', end ='')
#     if i == len(data[0])-1:
#         print('};')
#     else:
#         print(', ', end="")
# print('int trajKnee[] = {', end="")
# for i in range(len(data[0])):
#     print((data[1][i]*180/3.141592654), sep ='\t', end ='')
#     if i == len(data[0])-1:
#         print('};')
#     else:
#         print(', ', end="")






 #h is scaled by hm
# Out:
# data
# [[1.06916454 1.21664719 1.24246164 1.23194208 1.03682628 0.81371188
# double wrongtrajHip[] = {61.25861600039825, 69.7087491482241, 71.18780806305188, 70.58508172817811, 59.405769704678235, 46.62225624560048, 46.008515395774474, 35.77770226623574, 36.95024084625489, 44.98151217973731, 46.162958555987295, 60.42713458274867, 61.5765734757171, 62.792817295443264, 64.22150782932323, 65.95976990237614, 68.11702345393962, 70.7307103824766, 70.69739989364898, 70.19375858207249, 69.03892974415315, 68.01232392599373, 67.0261065754156, 65.9322401592695, 63.4992560482386, 63.035623285405755, 62.575558849876764, 62.12283726369728, 61.683426892192635, 61.25861600039825};
# double wrongtrajKnee[] = {118.39403547289555, 105.44179735976296, 104.7905363722772, 105.09957390474663, 111.38425991767903, 117.70635718320692, 118.00057014690016, 122.47900262689365, 122.08174766792213, 118.93024755220533, 118.46090013236194, 111.83769314731123, 111.26591181082536, 110.6470524000231, 109.91277664547201, 108.99764511288969, 107.8442057016788, 106.43213563834294, 108.39227403767366, 109.06768966477891, 110.58068207847849, 111.85821421537685, 113.02965586410114, 114.24925238197363, 116.66547765058422, 117.05194009670075, 117.41559153685475, 117.75849011348775, 118.08508010273958, 118.39403547289555};
# double wrongtrajHM[] = {1.9999999189177953, 1.154792662640137, 0.10006603078969141, 1.9999990330583683, 1.9999997871811577, 0.10000014654167723, 1.9999999464807965, 0.10000003855563055, 1.9999999968221012, 0.10000072645916798, 0.8850007387896254, 0.10000017791413639, 0.11359644315089769, 0.14320510336049008, 0.18941029859199135, 0.2666537079906902, 0.4249756794071423, 0.9339323627816619, 0.10000002141863401, 0.2211030869220899, 0.18651084764869152, 0.17455002306677797, 0.1916914576444776, 0.47295890684166303, 0.10000087194080189, 0.100001082701968, 0.10000011129249432, 0.100000115408191, 0.10000012031273015, 0.9939097279139237};

# %%
N = int(data[0][0])
print(data[0][0]) #m.coln, m.sgn,
tau_k_values = np.zeros(N)
tau_h_values = np.zeros(N)
thetal1_values = np.zeros(N)
thetal2_values = np.zeros(N)

for i in range (1,N):
    tau_k_values[i] = data[5][i]
    tau_h_values[i] =data[4][i]
    thetal1_values[i] =data[6][i]
    thetal2_values[i] =data[7][i]

    
f, axs = plt.subplots(2,2) #create axes



axs[0][0].plot(tau_h_values)    # top left : torque of hip
plt.text(-35, 275, 'tau_hip')


plt.title("Torque_hip")

axs[1][0].plot(tau_k_values)   # bottom left : torque of knee
plt.title("Torque_knee")

axs[0][1].plot(thetal1_values*180/3.141592654)  # top right : thetal1
plt.title("theta_l1")

axs[1][1].plot(thetal2_values*180/3.141592654)  # bottom right: thetal2
plt.title("theta_l2")
# plt.text(0.5, 0, 'titles')
# axs[1][1].title("Torque and theta")

# axs[0][0].title("thetal1")
# axs[1][0].title("thetal1")

# axs[0][1].title("thetal1")
# axs[1][1].title("thetal2")


# plt.title("Torque and theta")

# torque for upper leg can be exerted, since the body is attached to the 2 vertical rails (even when body removed from model)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-3-e3d462fd4d16> in <module>
# ----> 1 N = int(data[0][0])
#       2 print(data[0][0]) #m.coln, m.sgn,
#       3 tau_k_values = np.zeros(N)
#       4 tau_h_values = np.zeros(N)
#       5 thetal1_values = np.zeros(N)
#
# TypeError: only size-1 arrays can be converted to Python scalars

# %%
lenBod = data[1][0]
lenLeg1 = data[2][0]
lenLeg2 = data[3][0]
theta1 = data[6][:]
theta2 = data[7][:]

# xPlot = data[7][:]
zPlot = data[11][:]
zStart = data[18][0]
print("zStart = ", zStart)

# %%
fig1, ax1 = plt.subplots(1,1) #create axes
#ax1.set_aspect('equal')
print(zPlot)
def plot_robot(i,ax): #update function for animation
    ax.clear()
    ax.set_xlim([-0.75,0.75])    # choose scales according to 2:3 aspect ratio
    ax.set_ylim([-0.1,0.9])

    
#     thA = theta[i]
#     leg1_xt = 0 #xPlot[i]
#     leg1_yt = zPlot[i]
#     leg1_xb = lenBod*np.cos(thA) + 0 # xPlot[i]
#     leg1_yb = zPlot[i] - lenBod*np.sin(thA)
#     ax.plot([leg1_xt,leg1_xb],[leg1_yt,leg1_yb],color='xkcd:black')
    
#     #plot leg 2
#     Lt = 0.5*lenBod+ zPlot[i] - 0.5*lenLeg
#     Lb = 0.5*lenBod + zPlot[i] + 0.5*lenLeg
#     leg2_xt = Lt*np.cos(thA) + 0 #xPlot[i]
#     leg2_yt = zPlot[i] - Lt*np.sin(thA)
#     leg2_xb = Lb*np.cos(thA) + 0 #xPlot[i]
#     leg2_yb = zPlot[i] - Lb*np.sin(thA)
   
#     ax.plot([leg2_xt,leg2_xb],[leg2_yt,leg2_yb],color='xkcd:black')
    
    
     #plot leg 
    leg_xt = 0 
    leg_yt = zPlot[i] 
    leg_xb = 0 + lenLeg1*np.cos(theta1[i])
    leg_yb = zPlot[i] - lenLeg1*np.sin(theta1[i])
    ax.plot([leg_xt,leg_xb],[leg_yt,leg_yb],color='xkcd:black')
    
#     leg_xt = m.q0[i,'x'].value 
#     leg_yt = m.q0[i,'z'].value 
#     leg_xb = m.q0[i,'x'].value + m.l1.value*cos(m.q0[i,'theta_l1'].value)
#     leg_yb = m.q0[i,'z'].value - m.l1.value*sin(m.q0[i,'theta_l1'].value)
#     ax.plot([leg_xt,leg_xb],[leg_yt,leg_yb],color='xkcd:black')
    
    

    #plot leg2 
    leg2_xt = 0 + lenLeg1*np.cos(theta1[i])
    leg2_yt = zPlot[i] - lenLeg1*np.sin(theta1[i])
    leg2_xb = 0 + lenLeg1*np.cos(theta1[i]) + lenLeg2*np.cos(theta2[i])
    leg2_yb = zPlot[i] - lenLeg1*np.sin(theta1[i]) - lenLeg2*np.sin(theta2[i])
    ax.plot([leg2_xt,leg2_xb],[leg2_yt,leg2_yb],color='xkcd:blue')

    
    #plot ground
    ax.plot([-1.5,1.5],[0,0],color='xkcd:green')

    #plot starting height
    ax.plot([-1.5,1.5],[0.4,0.4],color='xkcd:orange')

    
update = lambda i: plot_robot(i,ax1) #lambdify update function

animate = ani.FuncAnimation(fig1,update,range(0,N),interval = 50 ,repeat=True)

HTML(animate.to_jshtml())
